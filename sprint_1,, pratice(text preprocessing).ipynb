# %%
import numpy as np #for numerical calculatoin
import pandas as pd # for data analysis
import re

# %%
data=pd.read_csv('DS3_C2_S1_Yelp_Data_Practice.csv') #importing data set with data

# %%
data
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 2     6oRAC4uyJCsJl1X0WZpVSA  2012-06-14  IESLBzqUCLdSzSqm0eCSxQ      4
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# ...                      ...         ...                     ...    ...
# 9995  VY_tvNUCCXGXQeSvJl757Q  2012-07-28  Ubyfp2RSDYW0g7Mbr8N3iA      3
# 9996  EKzMHI1tip8rC1-ZAy64yg  2012-01-18  2XyIOQKbVFb6uXQdJ0RzlQ      4
# 9997  53YGfwmbW73JhFiemNeyzQ  2010-11-16  jyznYkIbpqVmlsZxSDSypA      4
# 9998  9SKdOoDHcFoxK5ZtsgHJoA  2012-12-02  5UKq9WQE1qQbJ0DJbc-B6Q      2
# 9999  pF7uRzygyZsltbmVpjIyvw  2010-10-16  vWSmOhg2ID1MNZHaWapGbA      5
#
#                                                    text    type  \
# ...

# %% [markdown]
# # task 1

# %% [markdown]
# # reviews contain crash, amazing,tasty find how many are they

# %%
data_1=data.loc[data['text'].str.contains('crash')]
print(f'no of tweets containing crash:{len(data_1)}')
data_1.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# Out:
# no of tweets containing crash:11
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_5864\4123876935.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   data_1.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# <style type="text/css">
# #T_5e489_row0_col4, #T_5e489_row1_col4, #T_5e489_row2_col4, #T_5e489_row3_col4, #T_5e489_row4_col4, #T_5e489_row5_col4, #T_5e489_row6_col4, #T_5e489_row7_col4, #T_5e489_row8_col4, #T_5e489_row9_col4, #T_5e489_row10_col4 {
#   width: 800px;
# }
# </style>
# <table id="T_5e489">
#   <thead>
#     <tr>
#       <th id="T_5e489_level0_col0" class="col_heading level0 col0" >business_id</th>
#       <th id="T_5e489_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_5e489_level0_col2" class="col_heading level0 col2" >review_id</th>
#       <th id="T_5e489_level0_col3" class="col_heading level0 col3" >stars</th>
# ...

# %%
data_2=data.loc[data['text'].str.contains('amazing')]
print(f'no of tweets containing amazing:{len(data_2)}')
data_2.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# Out:
# no of tweets containing amazing:798
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_6368\2986646173.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   data_2.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# <style type="text/css">
# ...

# %%
data_k=data.loc[data['text'].str.contains('tasty')]
print(f'no of tweets containing tasty:{len(data_k)}')
data_k.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# Out:
# no of tweets containing tasty:716
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_6368\2450615959.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   data_k.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# <style type="text/css">
# ...

# %% [markdown]
# # task 2

# %% [markdown]
# # orginazation wants to know the datae of the review and the review id

# %%
print(' the date review_id which denote a good feedback using the word ",crash"\n ',data_1[['review_id','date']])
# Out:
#  the date review_id which denote a good feedback using the word ",crash"
#                      review_id        date
# 297   LYc0qoZTS8L0U_NvIaYwYA  2010-04-05
# 2469  V0EsJ8gw-NUFoiJcjcHb2Q  2007-07-20
# 3372  31jBo2afBbzqvGePhchbTQ  2009-02-01
# 3728  qq6nxekcC8GwkDEAA7w4Lw  2012-11-14
# 3753  OW2Pj5-ExHxuFoCQtRfIsw  2009-09-22
# 4026  yu32TrnceRwbGysd3_fHVQ  2012-09-02
# 6271  dnVxNsWk7WCTwm2_WicqJQ  2011-07-19
# 6316  HSenViZb--vlRB6Jjof46A  2012-01-18
# 8404  0y6tjRANTAx-KIbiCRcu3A  2011-05-19
# 8775  fcjwUTuRrgi66nZZb-Tb9w  2012-09-20
# 9189  gwbYi4ykkOKh3CKJXIbtcA  2012-01-27

# %% [markdown]
# # task 3

# %% [markdown]
# # perform the data cleaning for review

# %%
tweet_with_hashtag = data.loc[data["review_id"].str.contains("#")]

print(f"Number of tweets containing hashtags: {len(data)}")

# view the tweets that contain a hashtag
tweet_with_hashtag\
.style.set_properties(subset=['review_id'], **{'width': '800px'}).hide_index()
# Out:
# Number of tweets containing hashtags: 10000
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_5864\1972426828.py:7: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   .style.set_properties(subset=['review_id'], **{'width': '800px'}).hide_index()
# <style type="text/css">
# </style>
# <table id="T_ecc38">
#   <thead>
#     <tr>
#       <th id="T_ecc38_level0_col0" class="col_heading level0 col0" >business_id</th>
#       <th id="T_ecc38_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_ecc38_level0_col2" class="col_heading level0 col2" >review_id</th>
#       <th id="T_ecc38_level0_col3" class="col_heading level0 col3" >stars</th>
#       <th id="T_ecc38_level0_col4" class="col_heading level0 col4" >text</th>
#       <th id="T_ecc38_level0_col5" class="col_heading level0 col5" >type</th>
#       <th id="T_ecc38_level0_col6" class="col_heading level0 col6" >user_id</th>
# ...

# %%
tweets_with_URLs = data.loc[data["review_id"].str.contains("http")]

# view the number of tweets that contain a URL
print(f"Number of tweets containing URLs: {len(data)}")
# Out:
# Number of tweets containing URLs: 10000

# %%
tweets_with_URLs\
.style.set_properties(subset=['review_id'], **{'width': '800px'}).hide_index()
# Out:
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_5864\1839614504.py:2: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   .style.set_properties(subset=['review_id'], **{'width': '800px'}).hide_index()
# <style type="text/css">
# </style>
# <table id="T_19e6a">
#   <thead>
#     <tr>
#       <th id="T_19e6a_level0_col0" class="col_heading level0 col0" >business_id</th>
#       <th id="T_19e6a_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_19e6a_level0_col2" class="col_heading level0 col2" >review_id</th>
#       <th id="T_19e6a_level0_col3" class="col_heading level0 col3" >stars</th>
#       <th id="T_19e6a_level0_col4" class="col_heading level0 col4" >text</th>
#       <th id="T_19e6a_level0_col5" class="col_heading level0 col5" >type</th>
#       <th id="T_19e6a_level0_col6" class="col_heading level0 col6" >user_id</th>
#       <th id="T_19e6a_level0_col7" class="col_heading level0 col7" >cool</th>
# ...

# %% [markdown]
# # We need to create one long string containing all the tweets. This will be needed to perform operations using regular expressions.

# %%
tweet_string = " ".join(i for i in data["review_id"]) #List comprehension

tweet_string[0 : 2000]
# Out:
# 'fWKvX83p0-ka4JS3dc6E5A IjZ33sJrzXqU-0X6U8NwyA IESLBzqUCLdSzSqm0eCSxQ G-WvGaISbqqaMHlNnByodA 1uJFq2r5QfJG_6ExMRCaGw m2CKSsepBCoRYWxiRUsxAg riFQ3vxNpP4rWLk_CSri2A JL7GXJ9u4YMx7Rzs05NfiQ XtnfnYmnJYi71yIuGsXIUA jJAIXA46pU1swYyRCdfXtQ E11jzpKz9Kw5K7fuARWfRw 3rPt0LxF7rgmEUrznoH22w cGnKNX3I9rthE0-TH24-qA FvEEw1_OsrYdvwLV5Hrliw pfUwBKYYmUXeiwrhDluQcw HvqmdqWcerVWO3Gs6zbrOw HXP_0Ul-FCmA4f-k9CqvaQ j4SIzrIy0WrmW4yr4--Khg v0cTd3PNpYCkTyGKSpOfGA a0lCu-j2Sk_kHQsZi_eNgw MuqugTuR5DdIPcZ2IVP3aQ LmuKVFh03Uz318VKnUWrxA CQYc8hgKxV4enApDkx0IhA Dx9sfFU6Zn0GYOckijom-g cFtQnKzn2VDpBedy_TxlvA ChBeixVZerfFkeO0McdlbA kZ4TzrVX6qeF0OvrVTGVEw B5h25WK28rJjx4KHm4gr7g Y_ERKao0J5WsRiCtlKSNSA hre97jjSwon4bn1muHKOJg dtpJXC5p_sdWDLSobluJ3Q S9OVpXat8k5YwWCn6FAgXg -v-shjbxoj7hpU62yn6vag 2VTwjhOX3UUvgOGbxe4xfA Bk7F8IyBuOHVp6w3BAKVow ApKbwpYJdnhhgP4NbjQw2Q vUuFuf4LYxfqbZH3lYxJfw gNm48xplqt42p-NvCkzUBg 5V9lfjjlY7tkXgkcDUWYyg 1fRGR6XTTElRBZW_oDrpUA 2sG6LKzRz91l10stVHl8uQ fuY6Bf4EtW3UwrdLQJa9_Q UTWI0z7nV5zNJLWnOz9Z5A 7uzj6rJ7
# ...

# %% [markdown]
# # Let's clean up the data using "re" to use regular expressions ("RegEx").

# %%
tweet_string = re.sub("http\S+", "_URL_", tweet_string)
#tweet_string[0:2000]
# \S : matches any non-white space character and '+' indicate 1 or more occurrences 
#of the pattern to its left

# %% [markdown]
# # Remove extra white spaces from tweet so that there is only one space between the words.

# %%
tweet_string = re.sub(r'\s+',' ', tweet_string)

# %%
tweet_string[0:2000]
# Out:
# 'fWKvX83p0-ka4JS3dc6E5A IjZ33sJrzXqU-0X6U8NwyA IESLBzqUCLdSzSqm0eCSxQ G-WvGaISbqqaMHlNnByodA 1uJFq2r5QfJG_6ExMRCaGw m2CKSsepBCoRYWxiRUsxAg riFQ3vxNpP4rWLk_CSri2A JL7GXJ9u4YMx7Rzs05NfiQ XtnfnYmnJYi71yIuGsXIUA jJAIXA46pU1swYyRCdfXtQ E11jzpKz9Kw5K7fuARWfRw 3rPt0LxF7rgmEUrznoH22w cGnKNX3I9rthE0-TH24-qA FvEEw1_OsrYdvwLV5Hrliw pfUwBKYYmUXeiwrhDluQcw HvqmdqWcerVWO3Gs6zbrOw HXP_0Ul-FCmA4f-k9CqvaQ j4SIzrIy0WrmW4yr4--Khg v0cTd3PNpYCkTyGKSpOfGA a0lCu-j2Sk_kHQsZi_eNgw MuqugTuR5DdIPcZ2IVP3aQ LmuKVFh03Uz318VKnUWrxA CQYc8hgKxV4enApDkx0IhA Dx9sfFU6Zn0GYOckijom-g cFtQnKzn2VDpBedy_TxlvA ChBeixVZerfFkeO0McdlbA kZ4TzrVX6qeF0OvrVTGVEw B5h25WK28rJjx4KHm4gr7g Y_ERKao0J5WsRiCtlKSNSA hre97jjSwon4bn1muHKOJg dtpJXC5p_sdWDLSobluJ3Q S9OVpXat8k5YwWCn6FAgXg -v-shjbxoj7hpU62yn6vag 2VTwjhOX3UUvgOGbxe4xfA Bk7F8IyBuOHVp6w3BAKVow ApKbwpYJdnhhgP4NbjQw2Q vUuFuf4LYxfqbZH3lYxJfw gNm48xplqt42p-NvCkzUBg 5V9lfjjlY7tkXgkcDUWYyg 1fRGR6XTTElRBZW_oDrpUA 2sG6LKzRz91l10stVHl8uQ fuY6Bf4EtW3UwrdLQJa9_Q UTWI0z7nV5zNJLWnOz9Z5A 7uzj6rJ7
# ...

# %% [markdown]
# # Remove double quotes from the column User Id.

# %%
tweet_User_ID = " ".join(Tweet for Tweet in data["user_id"])

#tweet_User_ID

# %%
tweet_User_ID = re.sub('"', '', tweet_User_ID)

#tweet_User_ID

# %% [markdown]
# # task 4

# %% [markdown]
# # company wants to know which most review contain phenomena and find the average of the phenomena

# %%
data_p=data.loc[data['text'].str.contains('phenomena')]
print(f'no of tweets containing phenomena:{len(data_p)}')
data_p.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# Out:
# no of tweets containing phenomena:54
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_5864\359288865.py:3: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   data_p.style.set_properties(subset=['text'],**{'width':'800px'}).hide_index()
# <style type="text/css">
# ...

# %%
print(' the date review_id which denote a good feedback using the phenomenan ",crash"\n ',data_p[['review_id','date']])
# Out:
#  the date review_id which denote a good feedback using the phenomenan ",crash"
#                      review_id        date
# 0     fWKvX83p0-ka4JS3dc6E5A  2011-01-26
# 76    QqUj8brMiWkMicmlWtpPrw  2011-06-24
# 123   28guWjT8KRZKvMZkltdzew  2010-08-15
# 620   mIhNUhDZqzUM6xstFv7lGg  2011-03-25
# 716   wIQ3fPSi6KhB24wmcpO6Ow  2007-04-30
# 989   YbMpfJnxo7fMrF9q47XuWw  2011-09-18
# 1098  AHrqKpT07lviBm5PWtJwFQ  2009-08-07
# 1249  oYwWCGdemEwokONQWvRKyQ  2011-03-07
# 1297  LYT2pgW50hez3C-GUbc7Jg  2009-03-31
# 1476  3SdwdPIEFdXc2BSZN6VgTQ  2011-04-30
# 1881  EZNnS44Ffk11dC_Tl1XGvA  2012-06-15
# 1884  9Jcxcm6noFZfl2RfoWRyQQ  2012-01-21
# 1967  LtAsU-F4DE0dhUWTL51YpQ  2010-01-02
# 2226  nfYAVLPJjhwaOW6tF5HUTQ  2009-11-25
# 2278  1IwsfCWj32Q_rHtghr_EEA  2012-04-13
# 2311  8zw-XQNUZMRWMSDXA1nMXg  2010-04-21
# 2350  bWn6P7aSu9lipoVOe8VkUw  2009-03-26
# 2415  RK0roqYbTA-phbBM0EHUWA  2011-01-08
# 2544  iHIY4wvrRJ6bBkUXs-2C1A  2012-04-03
# 2635  XI7cL6UlNRdxZtQH7BCpCA  2012-04-30
# ...

# %%
l=data_p.mean()
l
# Out:
# C:\Users\SHAHID\AppData\Local\Temp\ipykernel_5864\1214364995.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   l=data_p.mean()
# stars     4.388889
# cool      1.351852
# useful    2.185185
# funny     1.074074
# dtype: float64

# %%
data.columns
# Out:
# Index(['business_id', 'date', 'review_id', 'stars', 'text', 'type', 'user_id',
#        'cool', 'useful', 'funny'],
#       dtype='object')

# %% [markdown]
# # task 5

# %% [markdown]
# # company is intrested to read the review of all the peoples whoes ratting is 5 and are not funny

# %%
df=data[(data.stars==5) & (data.funny== 0)]
df
# Out:
#                  business_id        date               review_id  stars  \
# 0     9yKzy9PApeiPPOUJEtnvkg  2011-01-26  fWKvX83p0-ka4JS3dc6E5A      5
# 1     ZRJwVLyzEJq1VAihDhYiow  2011-07-27  IjZ33sJrzXqU-0X6U8NwyA      5
# 3     _1QQZuf4zZOyFCvXc0o6Vg  2010-05-27  G-WvGaISbqqaMHlNnByodA      5
# 4     6ozycU1RpktNG2-1BroVtw  2012-01-05  1uJFq2r5QfJG_6ExMRCaGw      5
# 9     nMHhuYan8e3cONo3PornJA  2010-08-11  jJAIXA46pU1swYyRCdfXtQ      5
# ...                      ...         ...                     ...    ...
# 9975  EWMwV5V9BxNs_U6nNVMeqw  2007-10-20  g4LsVAoafmUDHiS-_yN4tA      5
# 9978  9Y3aQAVITkEJYe5vLZr13w  2010-04-01  ZoTUU6EJ1OBNr7mhqxHBLw      5
# 9989  mQUC-ATrFuMQSaDQb93Pug  2011-10-01  ta2P9joJqeFB8BzFp-AzjA      5
# 9991  WJ5mq4EiWYAA4Vif0xDfdg  2011-12-05  EuHX-39FR7tyyG1ElvN1Jw      5
# 9999  pF7uRzygyZsltbmVpjIyvw  2010-10-16  vWSmOhg2ID1MNZHaWapGbA      5
#
#                                                    text    type  \
# ...

# %%
m=re.sub("(\\d|\\w)+"," ",df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 m=re.sub("(\\d|\\w)+"," ",df)
#
# File ~\anaconda3\New folder\lib\re.py:209, in sub(pattern, repl, string, count, flags)
#     202 def sub(pattern, repl, string, count=0, flags=0):
#     203     """Return the string obtained by replacing the leftmost
#     204     non-overlapping occurrences of the pattern in string by the
#     205     replacement repl.  repl can be either a string or a callable;
#     206     if a string, backslash escapes in it are processed.  If it is
#     207     a callable, it's passed the Match object and must return
#     208     a replacement string to be used."""
# --> 209     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object
